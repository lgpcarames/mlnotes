# %% [markdown]
# # Regressão Linear: Reobtendo a Lei de Moore Usando o Tensorflow

# %%
# Importando o tensorflow
import tensorflow as tf
# Out:
# 2022-04-16 12:39:35.666914: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-16 12:39:35.666948: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Importando as demais bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
# Obtendo a base de dados
# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv

# %%
# Carregando a base de dados e trabalhando com ela
data = pd.read_csv("moore.csv", header=None).values
x = data[:, 0].reshape(-1,1)
y = data[:, 1]

# %%
plt.scatter(x,y)
plt.show()

# %%
# Sabendo que queremos um modelo linear, vamos tomar o logaritmo
y = np.log(y)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Vamos realizar um breve pré-processamento dos dados antes de construirmos o modelo, primeiramente vamos centralizar os dados em x.

# %%
x = x - x.mean()

# %%
# Agora podemos criar o nosso modelo no tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.SGD(0.001, 0.9), loss='mse')


# Criando uma agenda para o treinamento
def schedule(epoch, lr):
    if epoch >=50:
        return 0.0001
    return 0.001


scheduler = tf.keras.callbacks.LearningRateScheduler(schedule)

# Treinando o modelo
r = model.fit(x, y, epochs=200, callbacks=[scheduler])
# Out:
# Epoch 1/200
# 2022-04-16 12:39:39.145913: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-16 12:39:39.145945: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-16 12:39:39.145967: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (lucas-Inspiron-5566): /proc/driver/nvidia/version does not exist
# 2022-04-16 12:39:39.146300: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 6/6 [==============================] - 0s 2ms/step - loss: 367.3053 - lr: 0.0010
# Epoch 2/200
# 6/6 [==============================] - 0s 2ms/step - loss: 395.2309 - lr: 0.0010
# Epoch 3/200
# 6/6 [==============================] - 0s 1ms/step - loss: 309.3835 - lr: 0.0010
# Epoch 4/200
# 6/6 [==============================] - 0s 2ms/step - loss: 273.1751 - lr: 0.0010
# Epoch 5/200
# 6/6 [==============================] - 0s 2ms/step - loss: 237.9915 - lr: 0.0010
# Epoch 6/200
# 6/6 [==============================] - 0s 2ms/step - loss: 148.6836 - lr: 0.0010
# Epoch 7/200
# 6/6 [==============================] - 0s 2ms/step - loss: 97.7348 - lr: 0.0010
# Epoch 8/200
# 6/6 [==============================] - 0s 2ms/step - loss: 92.7638 - lr: 0.0010
# Epoch 9/200
# 6/6 [==============================] - 0s 2ms/step - loss: 59.7228 - lr: 0.0010
# Epoch 10/200
# 6/6 [==============================] - 0s 2ms/step - loss: 35.0790 - lr: 0.0010
# Epoch 11/200
# 6/6 [==============================] - 0s 2ms/step - loss: 26.7713 - lr: 0.0010
# Epoch 12/200
# 6/6 [==============================] - 0s 2ms/step - loss: 26.2739 - lr: 0.0010
# Epoch 13/200
# 6/6 [==============================] - 0s 2ms/step - loss: 16.3642 - lr: 0.0010
# Epoch 14/200
# 6/6 [==============================] - 0s 2ms/step - loss: 11.4626 - lr: 0.0010
# Epoch 15/200
# 6/6 [==============================] - 0s 2ms/step - loss: 7.3856 - lr: 0.0010
# Epoch 16/200
# 6/6 [==============================] - 0s 2ms/step - loss: 5.4620 - lr: 0.0010
# Epoch 17/200
# 6/6 [==============================] - 0s 2ms/step - loss: 5.2256 - lr: 0.0010
# Epoch 18/200
# 6/6 [==============================] - 0s 2ms/step - loss: 5.1767 - lr: 0.0010
# Epoch 19/200
# 6/6 [==============================] - 0s 2ms/step - loss: 6.5920 - lr: 0.0010
# Epoch 20/200
# 6/6 [==============================] - 0s 2ms/step - loss: 7.9634 - lr: 0.0010
# Epoch 21/200
# 6/6 [==============================] - 0s 2ms/step - loss: 4.0324 - lr: 0.0010
# Epoch 22/200
# 6/6 [==============================] - 0s 2ms/step - loss: 3.0074 - lr: 0.0010
# Epoch 23/200
# 6/6 [==============================] - 0s 2ms/step - loss: 2.0166 - lr: 0.0010
# Epoch 24/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.7340 - lr: 0.0010
# Epoch 25/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.8531 - lr: 0.0010
# Epoch 26/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.6172 - lr: 0.0010
# Epoch 27/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1585 - lr: 0.0010
# Epoch 28/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1433 - lr: 0.0010
# Epoch 29/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1181 - lr: 0.0010
# Epoch 30/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9576 - lr: 0.0010
# Epoch 31/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9340 - lr: 0.0010
# Epoch 32/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9396 - lr: 0.0010
# Epoch 33/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9006 - lr: 0.0010
# Epoch 34/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9417 - lr: 0.0010
# Epoch 35/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.2412 - lr: 0.0010
# Epoch 36/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.3160 - lr: 0.0010
# Epoch 37/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.3443 - lr: 0.0010
# Epoch 38/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.4364 - lr: 0.0010
# Epoch 39/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0849 - lr: 0.0010
# Epoch 40/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0249 - lr: 0.0010
# Epoch 41/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9406 - lr: 0.0010
# Epoch 42/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9042 - lr: 0.0010
# Epoch 43/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8885 - lr: 0.0010
# Epoch 44/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8923 - lr: 0.0010
# Epoch 45/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8845 - lr: 0.0010
# Epoch 46/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8810 - lr: 0.0010
# Epoch 47/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8760 - lr: 0.0010
# Epoch 48/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8784 - lr: 0.0010
# Epoch 49/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8916 - lr: 0.0010
# Epoch 50/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.0820 - lr: 0.0010
# Epoch 51/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0479 - lr: 1.0000e-04
# Epoch 52/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0687 - lr: 1.0000e-04
# Epoch 53/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8839 - lr: 1.0000e-04
# Epoch 54/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8978 - lr: 1.0000e-04
# Epoch 55/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8672 - lr: 1.0000e-04
# Epoch 56/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9001 - lr: 1.0000e-04
# Epoch 57/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9072 - lr: 1.0000e-04
# Epoch 58/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8913 - lr: 1.0000e-04
# Epoch 59/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9628 - lr: 1.0000e-04
# Epoch 60/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9005 - lr: 1.0000e-04
# Epoch 61/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8761 - lr: 1.0000e-04
# Epoch 62/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9056 - lr: 1.0000e-04
# Epoch 63/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8829 - lr: 1.0000e-04
# Epoch 64/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8760 - lr: 1.0000e-04
# Epoch 65/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8855 - lr: 1.0000e-04
# Epoch 66/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8910 - lr: 1.0000e-04
# Epoch 67/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8758 - lr: 1.0000e-04
# Epoch 68/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8855 - lr: 1.0000e-04
# Epoch 69/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8976 - lr: 1.0000e-04
# Epoch 70/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8872 - lr: 1.0000e-04
# Epoch 71/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8728 - lr: 1.0000e-04
# Epoch 72/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8720 - lr: 1.0000e-04
# Epoch 73/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8732 - lr: 1.0000e-04
# Epoch 74/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8711 - lr: 1.0000e-04
# Epoch 75/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8922 - lr: 1.0000e-04
# Epoch 76/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8734 - lr: 1.0000e-04
# Epoch 77/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8728 - lr: 1.0000e-04
# Epoch 78/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8738 - lr: 1.0000e-04
# Epoch 79/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8731 - lr: 1.0000e-04
# Epoch 80/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8731 - lr: 1.0000e-04
# Epoch 81/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8758 - lr: 1.0000e-04
# Epoch 82/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9135 - lr: 1.0000e-04
# Epoch 83/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9257 - lr: 1.0000e-04
# Epoch 84/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8761 - lr: 1.0000e-04
# Epoch 85/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8880 - lr: 1.0000e-04
# Epoch 86/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8716 - lr: 1.0000e-04
# Epoch 87/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8911 - lr: 1.0000e-04
# Epoch 88/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9048 - lr: 1.0000e-04
# Epoch 89/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8803 - lr: 1.0000e-04
# Epoch 90/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8780 - lr: 1.0000e-04
# Epoch 91/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8737 - lr: 1.0000e-04
# Epoch 92/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8716 - lr: 1.0000e-04
# Epoch 93/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8721 - lr: 1.0000e-04
# Epoch 94/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8723 - lr: 1.0000e-04
# Epoch 95/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8801 - lr: 1.0000e-04
# Epoch 96/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9159 - lr: 1.0000e-04
# Epoch 97/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8738 - lr: 1.0000e-04
# Epoch 98/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9060 - lr: 1.0000e-04
# Epoch 99/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9037 - lr: 1.0000e-04
# Epoch 100/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8826 - lr: 1.0000e-04
# Epoch 101/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8759 - lr: 1.0000e-04
# Epoch 102/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8743 - lr: 1.0000e-04
# Epoch 103/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8769 - lr: 1.0000e-04
# Epoch 104/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8726 - lr: 1.0000e-04
# Epoch 105/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8835 - lr: 1.0000e-04
# Epoch 106/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8827 - lr: 1.0000e-04
# Epoch 107/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8728 - lr: 1.0000e-04
# Epoch 108/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8762 - lr: 1.0000e-04
# Epoch 109/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8722 - lr: 1.0000e-04
# Epoch 110/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8706 - lr: 1.0000e-04
# Epoch 111/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8852 - lr: 1.0000e-04
# Epoch 112/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8820 - lr: 1.0000e-04
# Epoch 113/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8689 - lr: 1.0000e-04
# Epoch 114/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8756 - lr: 1.0000e-04
# Epoch 115/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8780 - lr: 1.0000e-04
# Epoch 116/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8758 - lr: 1.0000e-04
# Epoch 117/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8727 - lr: 1.0000e-04
# Epoch 118/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8716 - lr: 1.0000e-04
# Epoch 119/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8880 - lr: 1.0000e-04
# Epoch 120/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9029 - lr: 1.0000e-04
# Epoch 121/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8792 - lr: 1.0000e-04
# Epoch 122/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8767 - lr: 1.0000e-04
# Epoch 123/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8785 - lr: 1.0000e-04
# Epoch 124/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8743 - lr: 1.0000e-04
# Epoch 125/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8862 - lr: 1.0000e-04
# Epoch 126/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8753 - lr: 1.0000e-04
# Epoch 127/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9050 - lr: 1.0000e-04
# Epoch 128/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8823 - lr: 1.0000e-04
# Epoch 129/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8734 - lr: 1.0000e-04
# Epoch 130/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8799 - lr: 1.0000e-04
# Epoch 131/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8778 - lr: 1.0000e-04
# Epoch 132/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8958 - lr: 1.0000e-04
# Epoch 133/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9019 - lr: 1.0000e-04
# Epoch 134/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8786 - lr: 1.0000e-04
# Epoch 135/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8766 - lr: 1.0000e-04
# Epoch 136/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8726 - lr: 1.0000e-04
# Epoch 137/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8736 - lr: 1.0000e-04
# Epoch 138/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8658 - lr: 1.0000e-04
# Epoch 139/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8796 - lr: 1.0000e-04
# Epoch 140/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8733 - lr: 1.0000e-04
# Epoch 141/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8718 - lr: 1.0000e-04
# Epoch 142/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9093 - lr: 1.0000e-04
# Epoch 143/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8931 - lr: 1.0000e-04
# Epoch 144/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9019 - lr: 1.0000e-04
# Epoch 145/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8933 - lr: 1.0000e-04
# Epoch 146/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8806 - lr: 1.0000e-04
# Epoch 147/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8710 - lr: 1.0000e-04
# Epoch 148/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8689 - lr: 1.0000e-04
# Epoch 149/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8820 - lr: 1.0000e-04
# Epoch 150/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8847 - lr: 1.0000e-04
# Epoch 151/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8722 - lr: 1.0000e-04
# Epoch 152/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8722 - lr: 1.0000e-04
# Epoch 153/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8699 - lr: 1.0000e-04
# Epoch 154/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8708 - lr: 1.0000e-04
# Epoch 155/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8872 - lr: 1.0000e-04
# Epoch 156/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9006 - lr: 1.0000e-04
# Epoch 157/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8720 - lr: 1.0000e-04
# Epoch 158/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8740 - lr: 1.0000e-04
# Epoch 159/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8728 - lr: 1.0000e-04
# Epoch 160/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8742 - lr: 1.0000e-04
# Epoch 161/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8743 - lr: 1.0000e-04
# Epoch 162/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8806 - lr: 1.0000e-04
# Epoch 163/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8850 - lr: 1.0000e-04
# Epoch 164/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8736 - lr: 1.0000e-04
# Epoch 165/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8729 - lr: 1.0000e-04
# Epoch 166/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8719 - lr: 1.0000e-04
# Epoch 167/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8745 - lr: 1.0000e-04
# Epoch 168/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8783 - lr: 1.0000e-04
# Epoch 169/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8744 - lr: 1.0000e-04
# Epoch 170/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8722 - lr: 1.0000e-04
# Epoch 171/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8722 - lr: 1.0000e-04
# Epoch 172/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8782 - lr: 1.0000e-04
# Epoch 173/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8751 - lr: 1.0000e-04
# Epoch 174/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8707 - lr: 1.0000e-04
# Epoch 175/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8722 - lr: 1.0000e-04
# Epoch 176/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8712 - lr: 1.0000e-04
# Epoch 177/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8707 - lr: 1.0000e-04
# Epoch 178/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8764 - lr: 1.0000e-04
# Epoch 179/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8725 - lr: 1.0000e-04
# Epoch 180/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8819 - lr: 1.0000e-04
# Epoch 181/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9681 - lr: 1.0000e-04
# Epoch 182/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9532 - lr: 1.0000e-04
# Epoch 183/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8782 - lr: 1.0000e-04
# Epoch 184/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8906 - lr: 1.0000e-04
# Epoch 185/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8919 - lr: 1.0000e-04
# Epoch 186/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8798 - lr: 1.0000e-04
# Epoch 187/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8727 - lr: 1.0000e-04
# Epoch 188/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8714 - lr: 1.0000e-04
# Epoch 189/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8724 - lr: 1.0000e-04
# Epoch 190/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8710 - lr: 1.0000e-04
# Epoch 191/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8726 - lr: 1.0000e-04
# Epoch 192/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8791 - lr: 1.0000e-04
# Epoch 193/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8803 - lr: 1.0000e-04
# Epoch 194/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8733 - lr: 1.0000e-04
# Epoch 195/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8719 - lr: 1.0000e-04
# Epoch 196/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8791 - lr: 1.0000e-04
# Epoch 197/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8773 - lr: 1.0000e-04
# Epoch 198/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8719 - lr: 1.0000e-04
# Epoch 199/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8718 - lr: 1.0000e-04
# Epoch 200/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8733 - lr: 1.0000e-04

# %%
# plotando a função loss
plt.plot(r.history['loss'], label='loss', linewidth=2)
plt.legend(loc='best')
plt.show()

# %%
# Obtendo a inclinação da reta
# A inclinação da reta é a taxa de crescimento do número de transistors

print(model.layers)
print(model.layers[0].get_weights())
# Out:
# [<keras.layers.core.dense.Dense object at 0x7f4303e992b0>]
# [array([[0.33886534]], dtype=float32), array([17.761274], dtype=float32)]

# %%
# A inclinação da reta é:
a = model.layers[0].get_weights()[0][0,0]

# %% [markdown]
# Portanto, o tempo para dobrar o número de transistores pode ser dado por:

# %%
x = np.array(x).flatten()
y = np.array(y)
denominador = x.dot(x) - x.mean() * x.sum()
a = (x.dot(y) - y.mean() * x.sum())/denominador
b = (y.mean() * x.dot(x) - x.mean() * x.dot(y))/denominador
print(a, b)
print('Tempo para dobrar o número de transistores: ', np.log(2)/a)
# Out:
# 0.34168248738731316 17.764939393631764
# Tempo para dobrar o número de transistores:  2.0286295205239195

# %% [markdown]
# ## Parte 2: Realizando previsões

# %%
# Verificand ose a linha se ajusta aos dados
yhat = model.predict(x).flatten()
plt.scatter(x, y)
plt.plot(x, yhat, 'r-', label='prediction', linewidth=2)
plt.legend(loc='best')
plt.show()

# %%
# Calculo manual

    # Obtendo os pesos
w, b = model.layers[0].get_weights()

# Usando o reshape para retomar o formato original
x = x.reshape(-1, 1)

# (N x 1) x (1 x 1) + (1) --> (N x 1)
yhat2 = (x.dot(w) + b).flatten()


# Não podemos utilizar '==' para pontos fluantes
np.allclose(yhat, yhat2)
# Out:
# True

# %% [markdown]
# ## Parte 3: Salvando e Carregando um Modelo

# %%
model.save('moore_law.h5')

# %% [markdown]
# Agora vamos carregar o modelo e confirmar que ele ainda funciona.

# %%
model = tf.keras.models.load_model('moore_law.h5')
print(model.layers)
# Out:
# [<keras.layers.core.dense.Dense object at 0x7f4303f1e490>]

# %%
print()

# Verificand ose a linha se ajusta aos dados
yhat = model.predict(x).flatten()
plt.scatter(x, y)
plt.plot(x, yhat, 'r-', label='prediction', linewidth=2)
plt.legend(loc='best')
plt.show()
