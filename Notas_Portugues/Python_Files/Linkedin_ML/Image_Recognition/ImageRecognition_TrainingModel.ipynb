# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from pathlib import Path
# Out:
# 2022-03-30 16:09:14.070724: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-30 16:09:14.070937: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Load data set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize data set to 0-to-1 range
x_train = x_train.astype("float32")
x_test = x_test.astype("float32")
x_train = x_train / 255
x_test = x_test / 255


# Convert class to binary class matrices
# Our labels are single values from 0 to 9
# Instead, we want each label to be an array with on element set to 1
y_train = keras.utils.np_utils.to_categorical(y_train, 10)
y_test = keras.utils.np_utils.to_categorical(y_test, 10)

# %%
# Create a model and add layers
model = Sequential()

model.add(Conv2D(32, (3, 3), 
                 padding="same",
                 activation="relu",
                 input_shape=(32, 32, 3)
                )
         )
model.add(Conv2D(32, (3, 3), 
                activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


model.add(Conv2D(64, (3, 3),
                padding="same",
                activation="relu"
                )
         )

model.add(Conv2D(64, (3, 3),
                activation="relu"
                )
         )
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))



# Print a summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
# 2022-03-30 16:09:23.739952: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-30 16:09:23.740519: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-30 16:09:23.740736: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (lucas-Inspiron-5566): /proc/driver/nvidia/version does not exist
# 2022-03-30 16:09:23.745295: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
# Train the model

model.fit(
    x_train,
    y_train,
    batch_size=32,
    epochs=50,
    validation_data=(x_test, y_test),
    shuffle=True,
)


# Save neural network structure
model_structure = model.to_json()
f = Path("model_structure.json")
f.write_text(model_structure)

# Save neural network's trained weigths
model.save_weights("model_weights.h5")
# Out:
# 2022-03-30 16:09:24.854690: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 614400000 exceeds 10% of free system memory.
# Epoch 1/50
# 1563/1563 [==============================] - 155s 99ms/step - loss: 1.4974 - accuracy: 0.4541 - val_loss: 1.1485 - val_accuracy: 0.5899
# Epoch 2/50
# 1563/1563 [==============================] - 143s 91ms/step - loss: 1.0961 - accuracy: 0.6101 - val_loss: 0.9596 - val_accuracy: 0.6635
# Epoch 3/50
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.9559 - accuracy: 0.6638 - val_loss: 0.8063 - val_accuracy: 0.7192
# Epoch 4/50
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.8602 - accuracy: 0.6979 - val_loss: 0.7619 - val_accuracy: 0.7341
# Epoch 5/50
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.7985 - accuracy: 0.7188 - val_loss: 0.7448 - val_accuracy: 0.7424
# Epoch 6/50
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.7527 - accuracy: 0.7350 - val_loss: 0.7004 - val_accuracy: 0.7589
# Epoch 7/50
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.7199 - accuracy: 0.7480 - val_loss: 0.6914 - val_accuracy: 0.7613
# Epoch 8/50
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.6905 - accuracy: 0.7585 - val_loss: 0.6821 - val_accuracy: 0.7697
# Epoch 9/50
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.6608 - accuracy: 0.7679 - val_loss: 0.6648 - val_accuracy: 0.7708
# Epoch 10/50
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.6331 - accuracy: 0.7772 - val_loss: 0.6640 - val_accuracy: 0.7735
# Epoch 11/50
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.6177 - accuracy: 0.7827 - val_loss: 0.6502 - val_accuracy: 0.7777
# Epoch 12/50
# 1563/1563 [==============================] - 150s 96ms/step - loss: 0.5930 - accuracy: 0.7899 - val_loss: 0.6650 - val_accuracy: 0.7745
# Epoch 13/50
# 1563/1563 [==============================] - 148s 95ms/step - loss: 0.5800 - accuracy: 0.7952 - val_loss: 0.6564 - val_accuracy: 0.7819
# Epoch 14/50
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.5633 - accuracy: 0.8016 - val_loss: 0.6584 - val_accuracy: 0.7840
# Epoch 15/50
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.5458 - accuracy: 0.8085 - val_loss: 0.6350 - val_accuracy: 0.7868
# Epoch 16/50
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.5342 - accuracy: 0.8091 - val_loss: 0.6564 - val_accuracy: 0.7859
# Epoch 17/50
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.5246 - accuracy: 0.8141 - val_loss: 0.6680 - val_accuracy: 0.7811
# Epoch 18/50
# 1563/1563 [==============================] - 148s 95ms/step - loss: 0.5127 - accuracy: 0.8198 - val_loss: 0.6591 - val_accuracy: 0.7777
# Epoch 19/50
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.5052 - accuracy: 0.8214 - val_loss: 0.6231 - val_accuracy: 0.7901
# Epoch 20/50
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.4924 - accuracy: 0.8262 - val_loss: 0.6420 - val_accuracy: 0.7919
# Epoch 21/50
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.4913 - accuracy: 0.8278 - val_loss: 0.6603 - val_accuracy: 0.7927
# Epoch 22/50
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.4838 - accuracy: 0.8304 - val_loss: 0.6709 - val_accuracy: 0.7839
# Epoch 23/50
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.4742 - accuracy: 0.8330 - val_loss: 0.6906 - val_accuracy: 0.7756
# Epoch 24/50
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.4663 - accuracy: 0.8357 - val_loss: 0.6509 - val_accuracy: 0.7859
# Epoch 25/50
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.4642 - accuracy: 0.8365 - val_loss: 0.6361 - val_accuracy: 0.7911
# Epoch 26/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4594 - accuracy: 0.8386 - val_loss: 0.6707 - val_accuracy: 0.7833
# Epoch 27/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4456 - accuracy: 0.8446 - val_loss: 0.6348 - val_accuracy: 0.7964
# Epoch 28/50
# 1563/1563 [==============================] - 123s 79ms/step - loss: 0.4403 - accuracy: 0.8453 - val_loss: 0.6537 - val_accuracy: 0.7930
# Epoch 29/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4380 - accuracy: 0.8460 - val_loss: 0.6492 - val_accuracy: 0.7902
# Epoch 30/50
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.4340 - accuracy: 0.8489 - val_loss: 0.6795 - val_accuracy: 0.7926
# Epoch 31/50
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.4275 - accuracy: 0.8501 - val_loss: 0.6928 - val_accuracy: 0.7769
# Epoch 32/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4234 - accuracy: 0.8496 - val_loss: 0.6613 - val_accuracy: 0.7936
# Epoch 33/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4219 - accuracy: 0.8535 - val_loss: 0.6698 - val_accuracy: 0.7898
# Epoch 34/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4156 - accuracy: 0.8554 - val_loss: 0.6465 - val_accuracy: 0.7959
# Epoch 35/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4063 - accuracy: 0.8588 - val_loss: 0.6535 - val_accuracy: 0.7971
# Epoch 36/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4106 - accuracy: 0.8550 - val_loss: 0.6502 - val_accuracy: 0.7921
# Epoch 37/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4024 - accuracy: 0.8593 - val_loss: 0.6993 - val_accuracy: 0.7935
# Epoch 38/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4038 - accuracy: 0.8590 - val_loss: 0.6719 - val_accuracy: 0.7950
# Epoch 39/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.3982 - accuracy: 0.8619 - val_loss: 0.6518 - val_accuracy: 0.7961
# Epoch 40/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.3988 - accuracy: 0.8610 - val_loss: 0.6670 - val_accuracy: 0.7984
# Epoch 41/50
# 1563/1563 [==============================] - 124s 80ms/step - loss: 0.3901 - accuracy: 0.8636 - val_loss: 0.6707 - val_accuracy: 0.7923
# Epoch 42/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3875 - accuracy: 0.8650 - val_loss: 0.6971 - val_accuracy: 0.7877
# Epoch 43/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3868 - accuracy: 0.8650 - val_loss: 0.6609 - val_accuracy: 0.7878
# Epoch 44/50
# 1563/1563 [==============================] - 123s 78ms/step - loss: 0.3839 - accuracy: 0.8664 - val_loss: 0.6521 - val_accuracy: 0.7965
# Epoch 45/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.3857 - accuracy: 0.8674 - val_loss: 0.6763 - val_accuracy: 0.7910
# Epoch 46/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3819 - accuracy: 0.8675 - val_loss: 0.6988 - val_accuracy: 0.7904
# Epoch 47/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3783 - accuracy: 0.8686 - val_loss: 0.7198 - val_accuracy: 0.7870
# Epoch 48/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3697 - accuracy: 0.8708 - val_loss: 0.6641 - val_accuracy: 0.8021
# Epoch 49/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3703 - accuracy: 0.8707 - val_loss: 0.6949 - val_accuracy: 0.7922
# Epoch 50/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3716 - accuracy: 0.8724 - val_loss: 0.6872 - val_accuracy: 0.7949
